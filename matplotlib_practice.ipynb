# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()

# Add the legend.
plt.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label="Boston")
ax.set_ylim(0,45)
ax.set_title("PyBer Fare by Month")
ax.set_xlabel('Dates')
ax.set_ylabel('Fares($)')
ax.grid()
ax.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.barh(x_axis, y_axis, color="magenta", label = "Boston")
plt.gca().invert_yaxis()

plt.title("PyBer Fare by Month")
plt.xlabel("Fare(S)")
plt.ylabel("Date")
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# Skill Drill 5.1.6
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = "cyan", label = "Chicago")
ax.set_title("PyBer Fare by Month")
ax.set_xlabel('Fares($)')
ax.set_ylabel('Date')
# ax.gca().invert_yaxis()
plt.gca().invert_yaxis()
plt.legend()

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
plt.scatter( y_axis,x_axis, color = "red", label="Chicago")


plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()
plt.xlabel("Fare(S)")
plt.ylabel("Date")
plt.legend()

# %%
# Bubble Chart. 's' parameter must be equal to the floating -point decimal valeus of the y-axis by using s= y_axix. 


plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# multiplying y axis data by 3 to make the chart more legible and impactful

y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
#Using the list comprehension technique to multiply each data point in the y-axis.

plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Create a Scatter Plot Using the Object-Oriented Interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Create a Bubble Chart Using the Object-Oriented Interface.

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
#Skill Drill 5.1.7. Using the object-oriented approach, make the following change to yoru bubble chart.
#Change the color of the markers to sky blue.
fig, ax = plt.subplots()
# ax.scatter(x_axis, y_axis, color ="skyblue", )
# # Change the size of the markers to 5 times each data point.
# ax.scatter(x_axis, y_axis, s=[i*5 for i in y_axis], color ="skyblue" )
# # Make the color 20% transparent.
# ax.scatter(x_axis, y_axis, s=[i*5 for i in y_axis], color ="skyblue" , alpha =0.2)
# # Add a black edge color to the circles.
# ax.scatter(x_axis, y_axis, s=[i*5 for i in y_axis], color ="skyblue" , alpha =0.2, edgecolors = "black")
# Make the linewidth of the circles 2 points.
# ax.scatter(x_axis, y_axis, s=[i*5 for i in y_axis], color ="skyblue" , alpha =0.2, edgecolors = "black", linewidth=2)
# Add a legend for the city of Boston.
# ax.scatter(x_axis, y_axis, s=[i*5 for i in y_axis], 
#            color ="skyblue" , alpha =0.2, edgecolors = "black", linewidth=2, label ="city of Boston")
# Add a title.
ax.set_title("PyBer Fare by Month")
# Switch the axis so that the Fare($) data is on the x-axis.
ax.scatter(y_axis,x_axis, s=[i*5 for i in y_axis], 
           color ="skyblue" , alpha =0.2, edgecolors = "black",  linewidth=2, label ="city of Boston")
# Add a limit for the x-axis data.
# ax.set_xlim(0,45)
# Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()
ax.set_xlabel('Fares($)')
ax.set_ylabel('Date')
# Out:
# Text(0, 0.5, 'Date')
