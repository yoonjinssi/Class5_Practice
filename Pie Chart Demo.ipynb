# %%
import matplotlib.pyplot as plt

# %%
categories =['pants', 'shirts', 'outerwear', 'pajamas', 'underwear', 'shoes']

# %%
revenue = [25,15,5,20,10,25]

# %%
plt.pie(revenue)
plt.show()

# %%
plt.pie(revenue, labels=categories)
plt.show()

# %%
plt.pie(revenue, labels=categories, autopct="%1.1f%%")
plt.show()

# %%
explode=[0, .1, 0,0,0,0]

# %%
plt.pie(revenue, labels=categories, autopct="%1.1f%%", explode = explode)
plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
#increase the size of the pie chart by using 
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
#To add the percentage of each wedge on the pie chart,
# we use the autopct parameter and provide the format of one decimal place using .1f%.
#The % before and after the .1f% formats the number as a percentage.
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff8421f5bd0>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
# ...

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen","greenyellow",
          "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
# Create a Pie Chart Using the Object-Oriented Interface

fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
# Skill Drill 5.1.8

fig, ax = plt.subplots()
#fig, ax = plt.subplots(figsize=(8, 8))

colors = ["lavender", "paleturquoise", "lightblue", "thistle", "yellowgreen","greenyellow",
          "yellow", "darkkhaki", "gold", "bisque", "mistyrose", "honeydew"]
# plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis,labels=x_axis, shadow=True, autopct='%.1f%%', startangle=90,counterclock=False, colors=colors, 
      explode = explode_values, radius = 3)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff8210c98d0>,
# ...
#  [Text(0.34313557672257367, 3.2821118164967, 'Jan'),
#   Text(1.4352154829260868, 2.9715579276819155, 'Feb'),
#   Text(3.1177543792839955, 1.590474026966637, 'Mar'),
#   Text(3.1486512305253003, -0.9879248091385882, 'April'),
#   Text(1.7594079724815788, -2.7918602376136707, 'May'),
#   Text(-0.1813930335735829, -3.295010859977699, 'June'),
#   Text(-2.490326835563471, -2.459323535461008, 'July'),
#   Text(-3.224867806322045, -0.7001625752263856, 'Aug'),
#   Text(-3.2993929800735544, 0.06329267762823845, 'Sept'),
#   Text(-2.9962420078512375, 1.3829438999422892, 'Oct'),
#   Text(-1.9522152313020908, 2.6606119015504923, 'Nov'),
#   Text(-0.6842293915450312, 3.228285944544863, 'Dec')],
#  [Text(0.18716486003049468, 1.7902428089981997, '3.3%'),
#   Text(0.7828448088687745, 1.62084977873559, '7.7%'),
#   Text(1.7815739310194258, 0.9088423011237924, '13.0%'),
#   Text(1.7174461257410725, -0.5388680777119571, '11.7%'),
# ...
